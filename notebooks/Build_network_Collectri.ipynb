# %% [markdown]
# *Builing the network*
# This network is interested on different nodes:
# - Ridge ~300 genes
# - Catboost ~300 genes
# - Top 10 DE genes (stat) for each of the groups
# -
#
#   For this one the rest of the DE genes will not be included because the DE data will be included as part of the metadata of the genes

# %% [markdown]
# The combining of the DE genes was done on Combine_DDS notebooks in this folder.
# The table was saved on "results/RNAseq_abundance_adjusted_combat_inmose_DE_stat.csv"

# %%
import pandas as pd

# %%
stats_de_df = pd.read_csv("results/RNAseq_abundance_adjusted_combat_inmose_DE_stat.csv", index_col=0)

# %%
stats_de_df
# Out:
#                       yo        ym        mo
# CFH            -3.591853       NaN       NaN
# SEMA3F         -5.309781       NaN -3.715063
# CFTR           -3.764250       NaN -3.576374
# RAD52          -3.308553       NaN       NaN
# MYH16           9.615413       NaN  5.476992
# ...                  ...       ...       ...
# Unnamed: 34254 -3.841096       NaN       NaN
# Unnamed: 34260 -3.993960       NaN       NaN
# Unnamed: 34273 -3.105884       NaN -3.852138
# PDE4C.1        -4.137821  4.253272 -7.671049
# Unnamed: 34313 -2.710037       NaN       NaN
#
# [3555 rows x 3 columns]
