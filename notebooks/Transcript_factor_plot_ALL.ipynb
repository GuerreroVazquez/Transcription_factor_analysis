# %% [markdown]
# # Transcriptor factor all

# %%
import scanpy as sc
import decoupler as dc

# Only needed for processing
import numpy as np
import pandas as pd
from anndata import AnnData
import pandas as pd
import yaml

# %%
def plot_personalize_bars(tf_df, title="", top=20, 
                          lFCs_thr=0.5, sig_thr=0.05,
                          sig = 'padj', title_fontsize=14, 
                          figsize=(5, 5), vertical=True):
    # Generate the volcano plot


    fig = dc.plot_barplot(
        acts=tf_df,
        contrast=comparison,
        top=top,
        vertical=True,
        figsize=figsize,
        dpi=100,
        return_fig=True
    )
    
    # Access the Axes object from the figure
    ax = fig.gca()
    
    # Add a title and remove the outer black line
    ax.set_title(title, fontsize=title_fontsize)
    for spine in ax.spines.values():
        spine.set_visible(False)  # Hide all outer spines
    
    return fig, ax

# %%
dds_files_path = '../data/dds_files.yml'
pvalue = 0.1

# %%
with open(dds_files_path, 'r') as file:
    dds_dict = yaml.safe_load(file)

# %%
tf_dict = {}
for dds in dds_dict.keys():
    comparison = dds[:-5]
    file = f'results/tf_acts_{comparison}.csv'
    tf_df = pd.read_csv(file, index_col=0)
    tf_dict[dds]=tf_df.copy()

# %%
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import rcParams
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for comparison, tf_df in tf_dict.items():
    print(comparison)
    tf_df = tf_df[tf_df['pvals']<pvalue]
    tf_acts=pd.DataFrame(tf_df[comparison])
    tf_acts=tf_acts.T
    values = tf_acts.iloc[0]
    down_reg = values.sort_values(ascending=True)[:5].index.to_list()
    up_reg = values.sort_values(ascending=False)[:5].index.to_list()
    up_down_reg = down_reg.copy()
    up_down_reg.extend(up_reg)
    print(up_down_reg)
    if len(up_down_reg)>0:
        fig, ax = plot_personalize_bars(tf_acts, title=comparison, top=30, figsize=(5, 10))
        fig.savefig(f"results/{comparison}_TF_Bar.png", bbox_inches='tight')

# %%
output_file =  'Transcriptor_factor_plot.pdf'
with PdfPages(output_file) as pdf:
    for comparison, tf_df in tf_dict.items():
        print(comparison)
        tf_df = tf_df[tf_df['pvals']<pvalue]
        tf_acts=pd.DataFrame(tf_df[comparison])
        tf_acts=tf_acts.T
        values = tf_acts.iloc[0]
        down_reg = values.sort_values(ascending=True)[:5].index.to_list()
        up_reg = values.sort_values(ascending=False)[:5].index.to_list()
        up_down_reg = down_reg.copy()
        up_down_reg.extend(up_reg)
        print(up_down_reg)
        if len(up_down_reg)>0:
            fig, ax = plot_personalize_bars(tf_acts, title=comparison, top=30, figsize=(5, 10))           
            # Save the figure to the PDF
            pdf.savefig(fig)
            # Close the figure after saving it to free up memory
            plt.close(fig)
# Out:
# yo_file
# ['PLAG1', 'FOXJ1', 'HNF1B', 'HEYL', 'MEOX1', 'PPARGC1A', 'NCOA6', 'ZFPM2', 'NR5A2', 'ZBTB4']
# ym_file
# ['SRSF2', 'NR0B1', 'PLAG1', 'SALL4', 'MBD1', 'SALL3', 'ZFPM2', 'RXRA', 'ESRRA', 'PHF20']
# mo_file
# ['SALL3', 'LRRFIP1', 'CTNNB1', 'SF1', 'SP1', 'OLIG2', 'POU2F3', 'FOXL2', 'ZBTB4', 'NR2F6']
# yo_F_file
# ['NEUROG3', 'ZNF382', 'HNF1B', 'KLF17', 'SP6', 'MYC', 'TP53', 'SP1', 'HIF1A', 'AR']
# yo_M_file
# ['FGF2', 'JUN', 'JUNB', 'RELA', 'SREBF1', 'RORC', 'RXRA', 'ESRRA', 'CEBPE', 'ESRRG']
# ym_F_file
# []
# ym_M_file
# ['MYC', 'ZBTB4', 'MYOD1', 'MYOG', 'TP53', 'RXRA', 'HNF1A', 'CTNNB1', 'TCF7', 'TFAP2D']
# mo_F_file
# ['RREB1', 'E2F5', 'ZNF382', 'TCF7L1', 'HNF1A', 'MYC', 'TP53', 'HIF1A', 'AR', 'ESR1']
# mo_M_file
# ['CTNNB1', 'KLF12', 'HNF1A', 'HOXB4', 'LHX8', 'ZBTB4', 'MYC', 'NEUROG1', 'FOXO1', 'TP53']
# mf_y_file
# ['STAT5B', 'E2F7', 'AIRE', 'MEF2C', 'ATF6', 'FOXN4', 'NEUROD6', 'NEUROD2', 'ATOH7', 'RXRA']
# mf_m_file
# ['HNF1A', 'HNF1B', 'RXRA', 'FOXF1', 'TCF7', 'MYC', 'TP53', 'ZBTB4', 'MYOG', 'MYOD1']
# mf_o_file
# ['HNF1A', 'MESP2', 'HNF1B', 'CREB5', 'ZHX2', 'MYC', 'MEF2A', 'MYOD1', 'MEF2C', 'ZBTB4']

# %%
tf_df
# Out:
# Empty DataFrame
# Columns: [ym_F_file, pvals]
# Index: []

# %%
tf_df = tf_df[tf_df['pvals']<0.1]
tf_acts=pd.DataFrame(tf_df[comparison])
tf_acts=tf_acts.T
tf_acts

# %%
values = tf_acts.iloc[0]
values

# %%
down_reg = values.sort_values(ascending=True)[:5].index.to_list()
up_reg = values.sort_values(ascending=False)[:5].index.to_list()
up_down_reg = down_reg.copy()
up_down_reg.extend(up_reg)
up_down_reg

# %%
dc.plot_barplot(
    acts=tf_acts,
    contrast=comparison,
    top=10,
    vertical=True,
    figsize=(3, 3)
)

# %%
fig, ax = plot_personalize_bars(tf_acts, title=comparison, top=30, figsize=(5, 10))

# %%
fig.savefig(f"results/{experiment}_{comparison}_TF_Bar.png", bbox_inches='tight')

# %%
comparison
